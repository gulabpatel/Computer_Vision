# %% [markdown]
# <a href="https://colab.research.google.com/github/gulabpatel/Computer_Vision/blob/main/0.3%3A%20Data_Collection_for_Image_Classification_Bing_Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader

# %%
# !mkdir images
# Out:
# mkdir: cannot create directory ‘images’: File exists

# %%
from bing_image_downloader import downloader
downloader.download("elephant in africa", limit=5,  output_dir='images', adult_filter_off=True, force_replace=False)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 5 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://static.horizontimes.com/wp-content/uploads/2017/07/13095652/African-Elephant.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://c402277.ssl.cf1.rackcdn.com/photos/12637/images/magazine_medium/Medium_WW22456.jpg?1477667080
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://2.bp.blogspot.com/-TfU95f5pIvw/UiyzO8zKcNI/AAAAAAAAYS8/KlgwLt5S7Is/s1600/African+Elephant+Wallpapers+%25285%2529.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://r7h9p6s7.stackpathcdn.com/wp-content/uploads/2005/11/african-elephant-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.the-open-mind.com/wp-content/uploads/2019/02/CATERS_PINK_ELEPHANT07.jpg
# [%] File Downloaded !

# %%
downloader.download("kangaroo in australia", limit=5,  output_dir='images', adult_filter_off=True, force_replace=False)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 5 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://cdn.newsapi.com.au/image/v1/c9c38750fa3fbd99d79a0b732ef5378f
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.hindustantimes.com/rf/image_size_960x540/HT/p2/2018/08/15/Pictures/red-kangaroo-outback-grasslands-in-the-australian_5cd01cb2-a092-11e8-9345-8d51f8ed9678.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.economist.com/sites/default/files/images/print-edition/20180317_ASP002_0.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://cdn.audleytravel.com/-/-/79/196047209238240012100129019106233061076063180195.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://a57.foxnews.com/a57.foxnews.com/static.foxnews.com/foxnews.com/content/uploads/2018/09/640/320/1862/1048/Eastern20Grey20Kangaroo.jpg?ve=1&amp;tl=1?ve=1&amp;tl=1
# [%] File Downloaded !

# %%
# !ls images/ -alrt
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Dec 15 17:22  ..
# drwxr-xr-x 2 root root 4096 Dec 15 17:22 'elephant in africa'
# drwxr-xr-x 4 root root 4096 Dec 15 17:22  .
# drwxr-xr-x 2 root root 4096 Dec 15 17:22 'kangaroo in australia'

# %%
# !ls 'images'/'elephant in africa'
# Out:
# Image_1.jpg  Image_2.jpg  Image_3.jpg  Image_4.jpg  Image_5.jpg

# %%
# !ls 'images'/'kangaroo in australia'
# Out:
# Image_1.jpg  Image_2.jpg  Image_3.jpg  Image_4.jpg  Image_5.jpg

# %%
from IPython.display import Image
Image("images/elephant in africa/Image_1.jpg")

# %%
Image("images/elephant in africa/Image_2.jpg")

# %%
Image("images/kangaroo in australia/Image_3.jpg")

# %%
from six import BytesIO
from PIL import Image
import numpy as np
import glob
import os

import matplotlib
import matplotlib.pyplot as plt

# %%
img_data = open('/content/images/elephant in africa/Image_1.jpg', 'rb').read()
image = Image.open(BytesIO(img_data))
(im_width, im_height) = image.size
np.array(image.getdata())
# Out:
# array([[173, 193, 217],
#        [173, 193, 217],
#        [172, 194, 218],
#        ...,
#        [106, 118,   8],
#        [113, 126,  20],
#        [ 94, 111,   7]])

# %%
def load_image_into_numpy_array(path):
  img_data = open(path, 'rb').read()
  image = Image.open(BytesIO(img_data))
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape((im_height, im_width, 3)).astype(np.uint8)

# %%
elephant_image_path = "/content/images/elephant in africa/*"
elephant_images_np = []
for iname in glob.glob(elephant_image_path):
  elephant_images_np.append(load_image_into_numpy_array(iname))

# %%
plt.rcParams['figure.figsize'] = [14, 7]

for idx, elephant_image_np in enumerate(elephant_images_np):
  plt.subplot(2, 3, idx+1)
  plt.imshow(elephant_image_np)
plt.show()

# %% [markdown]
# ---------------
