# %% [markdown]
# Help is available on https://www.youtube.com/watch?v=oXlwWbU8l2o&t=1123s

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow

# %%
img = cv.imread("photo.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=235x300 at 0x7FEB319B5AC8>

# %% [markdown]
# #BGR to Grayscal

# %%
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=235x300 at 0x7FEB318CBE80>

# %% [markdown]
# #BGR to HSV
#
# (HUE, ATURATION, VALUE)

# %%
hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)
cv2_imshow(hsv)
# Out:
# <PIL.Image.Image image mode=RGB size=235x300 at 0x7FEB318CB978>

# %% [markdown]
# #BGR to L*a*b

# %%
lab = cv.cvtColor(img, cv.COLOR_BGR2LAB)
cv2_imshow(lab)
# Out:
# <PIL.Image.Image image mode=RGB size=180x200 at 0x7F244BA1BEF0>

# %% [markdown]
# #BGR to RGB

# %%
rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv2_imshow(rgb)
# Out:
# <PIL.Image.Image image mode=RGB size=235x300 at 0x7FEB2FFECDD8>

# %% [markdown]
# #Split the  image channels

# %%
b,g,r = cv.split(img)
cv2_imshow(b)
cv2_imshow(g)
cv2_imshow(r)
# Out:
# <PIL.Image.Image image mode=L size=235x300 at 0x7FEB2826FEB8>
# <PIL.Image.Image image mode=L size=235x300 at 0x7FEB2826F208>
# <PIL.Image.Image image mode=L size=235x300 at 0x7FEB2826F240>

# %% [markdown]
# #Merge B,G,R channels

# %%
merged = cv.merge([b,g,r])
cv2_imshow(merged)
# Out:
# <PIL.Image.Image image mode=RGB size=235x300 at 0x7FEB2827B860>
